# %% [markdown]
# # curd create update read delete

# %%
import pandas as pd

# %%
import sqlite3

# %%
con = sqlite3.connect("Data/weather_2012.sqlite")
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3",con)
df
# Out:
#    id            date_time  temp
# 0   1  2012-01-01 00:00:00  -1.8
# 1   2  2012-01-01 01:00:00  -1.8
# 2   3  2012-01-01 02:00:00  -1.8

# %%
df = pd.read_sql("SELECT * from weather_2012",con,index_col='id')
df
# Out:
#                date_time  temp
# id
# 1    2012-01-01 00:00:00  -1.8
# 2    2012-01-01 01:00:00  -1.8
# 3    2012-01-01 02:00:00  -1.8
# 4    2012-01-01 03:00:00  -1.5
# 5    2012-01-01 04:00:00  -1.5
# ..                   ...   ...
# 96   2012-01-04 23:00:00  -9.6
# 97   2012-01-05 00:00:00  -8.8
# 98   2012-01-05 01:00:00  -7.5
# 99   2012-01-05 02:00:00  -5.4
# 100  2012-01-05 03:00:00  -5.0
#
# [100 rows x 2 columns]

# %%
df.head()
# Out:
#               date_time  temp
# id
# 1   2012-01-01 00:00:00  -1.8
# 2   2012-01-01 01:00:00  -1.8
# 3   2012-01-01 02:00:00  -1.8
# 4   2012-01-01 03:00:00  -1.5
# 5   2012-01-01 04:00:00  -1.5

# %%
df.tail()
# Out:
#                date_time  temp
# id
# 96   2012-01-04 23:00:00  -9.6
# 97   2012-01-05 00:00:00  -8.8
# 98   2012-01-05 01:00:00  -7.5
# 99   2012-01-05 02:00:00  -5.4
# 100  2012-01-05 03:00:00  -5.0

# %%
df.describe()
# Out:
#              temp
# count  100.000000
# mean    -6.841000
# std      7.774487
# min    -18.600000
# 25%    -14.825000
# 50%     -7.450000
# 75%      0.350000
# max      5.300000

# %%
df.isna()
# Out:
#      date_time   temp
# id
# 1        False  False
# 2        False  False
# 3        False  False
# 4        False  False
# 5        False  False
# ..         ...    ...
# 96       False  False
# 97       False  False
# 98       False  False
# 99       False  False
# 100      False  False
#
# [100 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1 to 100
# Data columns (total 2 columns):
# date_time    100 non-null object
# temp         100 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 2.3+ KB

# %%
df.columns
# Out:
# Index(['date_time', 'temp'], dtype='object')

# %%
weather_df = pd.read_csv("https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/weather_2012.csv")
weather_df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                   4              8.0           101.24                   Fog
# 1                   4              8.0           101.24                   Fog
# 2                   7              4.0           101.26  Freezing Drizzle,Fog
# 3                   6              4.0           101.27  Freezing Drizzle,Fog
# 4                   7              4.8           101.23                   Fog
# ...               ...              ...              ...                   ...
# 8779               30              9.7           100.13                  Snow
# 8780               24              9.7           100.03                  Snow
# 8781               28              4.8            99.95                  Snow
# 8782               28              9.7            99.91                  Snow
# 8783               30             11.3            99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
con = sqlite3.connect("weather_df.sqlite")
con

# %%
con.execute("DROP TABLE IF EXISTS weather_2012")

# %%
weather_df.to_sql("weather_2012",con)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py:2712: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
con = sqlite3.connect("weather_df.sqlite")
df = pd.read_sql("SELECT * from weather_2012 LIMIT 10", con)
df
# Out:
#    index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0      0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1      1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2      2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3      3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4      4  2012-01-01 04:00:00      -1.5                -3.3           88
# 5      5  2012-01-01 05:00:00      -1.4                -3.3           87
# 6      6  2012-01-01 06:00:00      -1.5                -3.1           89
# 7      7  2012-01-01 07:00:00      -1.4                -3.6           85
# 8      8  2012-01-01 08:00:00      -1.4                -3.6           85
# 9      9  2012-01-01 09:00:00      -1.3                -3.1           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
# 5                9              6.4           101.27                   Fog
# 6                7              6.4           101.29                   Fog
# 7                7              8.0           101.26                   Fog
# 8                9              8.0           101.23                   Fog
# 9               15              4.0           101.20                   Fog

# %%
con = sqlite3.connect("weather_df.sqlite")
df = pd.read_sql("SELECT * from weather_2012 ORDER BY Weather", con)
df
# Out:
#       index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0        67  2012-01-03 19:00:00     -16.9               -24.8           50
# 1       114  2012-01-05 18:00:00      -7.1               -14.4           56
# 2       115  2012-01-05 19:00:00      -9.2               -15.4           61
# 3       116  2012-01-05 20:00:00      -9.8               -15.7           62
# 4       117  2012-01-05 21:00:00      -9.0               -14.8           63
# ...     ...                  ...       ...                 ...          ...
# 8779   6188  2012-09-14 20:00:00      16.5                15.8           96
# 8780   4323  2012-06-29 03:00:00      19.5                16.1           81
# 8781   4761  2012-07-17 09:00:00      22.9                21.3           91
# 8782   5108  2012-07-31 20:00:00      22.4                18.7           80
# 8783   4757  2012-07-17 05:00:00      20.6                18.6           88
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# 0                  24             25.0           101.74
# 1                  11             25.0           100.71
# 2                   7             25.0           100.80
# 3                   9             25.0           100.83
# 4                  13             25.0           100.83
# ...               ...              ...              ...
# 8779               22             16.1           101.06
# 8780                7              9.7            99.71
# 8781               17              9.7            99.84
# 8782               35              9.7           100.64
# 8783               19              4.8           100.08
#
#                              Weather
# 0                              Clear
# 1                              Clear
# 2                              Clear
# 3                              Clear
# 4                              Clear
# ...                              ...
# 8779      Thunderstorms,Rain Showers
# 8780  Thunderstorms,Rain Showers,Fog
# 8781  Thunderstorms,Rain Showers,Fog
# 8782  Thunderstorms,Rain Showers,Fog
# 8783          Thunderstorms,Rain,Fog
#
# [8784 rows x 9 columns]

# %%
import MYSQLdb
con = MYSQLdb.connect(host='localhost',db="test")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-6498216a1689> in <module>
# ----> 1 import MYSQLdb
#       2 con = MYSQLdb.connect(host='localhost',db="test")
#
# ModuleNotFoundError: No module named 'MYSQLdb'

# %%
import psycopg2
con = psycopg2.connect(host="localhost")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-ee56b093fc5b> in <module>
# ----> 1 import psycopg2
#       2 con = psycopg2.connect(host="localhost")
#
# ModuleNotFoundError: No module named 'psycopg2'
